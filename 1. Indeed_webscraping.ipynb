# %% [markdown]
# # Webscraping using the requests library
# ## Import necessary libraries
#
#
#    - In this notebook, I will use `requests` and `BeautifulSoup` libraries to scrape job postings from Indeed website.
#    - Initially, data was scraped from Glassdoor and Monster as well, but there were many overlaps between the job aggregate sites, and Indeed being the largest one, it was sufficient to obtain data solely from Indeed for now.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
url = 'https://www.indeed.com/jobs?q=Data+%26+Database&l=san+francisco%2C+ca&sort=date&start=80' # This is a string of a URL that we want to grab info from
res = requests.get(url)

# %% [markdown]
# ### Get status codes|

# %%
res.status_code
# Out:
# 200

# %%
res.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr">\n<head>\n<meta http-equiv="content-type" content="text/html;charset=UTF-8">\n<script type="text/javascript" src="//d3fw5vlhllyvee.cloudfront.net/s/ffe72ff/en_US.js"></script>\n<link href="//d3fw5vlhllyvee.cloudfront.net/s/105b986/jobsearch_all.css" rel="stylesheet" type="text/css">\n<link rel="alternate" type="application/rss+xml" title="Data &amp; Database Jobs, Employment in San Francisco, CA" href="https://rss.indeed.com/rss?q=Data+%26+Database&l=san+francisco%2C+ca&sort=date">\n<link rel="alternate" media="only screen and (max-width: 640px)" href="/m/jobs?q=Data+%26+Database&l=san+francisco%2C+ca&sort=date">\n\n<script type="text/javascript">\n\nif (typeof window[\'closureReadyCallbacks\'] == \'undefined\') {\nwindow[\'closureReadyCallbacks\'] = [];\n}\n\nfunction call_when_jsall_loaded(cb) {\nif (window[\'closureReady\']) {\ncb();\n} else {\nwindow[\'closureReadyCallbacks\'].push(cb);\n}\n}\n</script>\n<meta name="ppstriptst" content="1">\n<script>\nvar _scriptDownloadCount = 0;\nvar _retryDownload = function() {\nvar script = document.createElement(\'script\');\nvar path = \'//d3fw5vlhllyvee.cloudfront.net/s/8dc1c1a/jobsearch-all-compiled.js\';\nscript.async = false;\nscript.src = path;\nscript.onerror=_onMainJSBundleError;\ndocument.head.appendChild(script);\n};\nvar _onMainJSBundleError = function() {\ntry {\n\n// for failed downloads, we want to retry the download up to 5 times\nif (_scriptDownloadCount < 4) {\n_scriptDownloadCount++;\n_retryDownload();\nreturn;\n}\n\n// if we\'ve exhausted all retries, send a ping to log the failure\nvar img = document.createElement("img");\nvar tk = "1eurcashao2i0801"; // tk\nimg.src = "/rpc/log?a=jasxJsLoadError&tk=" + tk;\ndocument.head.appendChild(img);\ndocument.head.removeChild(img);\n\n} catch(e) {}\n}\n\n</script>\n\n<script type="text/javascript" src="//d3fw5vlhllyvee.cloudfront.net/s/8dc1c1a/jobsearch-all-compiled.js" onerror="_onMainJSBundleError()" crossorigin="anonymous"></script>\n<script type="text/javascript">\n\nvar searchUID = \'1eurcashao2i0801\';\nvar tk = \'1eurcashao2i0801\';\n\nvar loggedIn = false;\nvar dcmPayload = \'jobse0;jobal0;viewj0;savej0;6927552\';\nvar myindeed = true;\nvar userEmail = \'\';\nvar tellFriendEmail = \'\';\nvar globalLoginURL = \'https:\\/\\/www.indeed.com\\/account\\/login?dest=%2Fjobs%3Fq%3DData%2B%2526%2BDatabase%26l%3Dsan%2Bfrancisco%2C%2Bca%26sort%3Ddate\';\nvar globalRegisterURL = \'https:\\/\\/www.indeed.com\\/account\\/register?dest=%2Fjobs%3Fq%3DData%2B%2526%2BDatabase%26l%3Dsan%2Bfrancisco%2C%2Bca%26sort%3Ddate\';\nvar searchKey = \'570df92e622882e9\';\nvar searchState = \'q=Data+%26+Database&amp;l=san+francisco%2C+ca&amp;sort=date\';\nvar searchQS = \'q=Data+%26+Database&l=san+francisco,+ca&sort=date\';\nvar eventType = \'jobsearch\';\nvar locale = \'en_US\';\nfunction clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf(\'&jsa=\'); if (si > 0) return; var jsh = hr + \'&tk=1eurcashao2i0801&jsa=9130\'; a.href = jsh; }\nfunction sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf(\'&oc=1\'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }\nfunction sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + \'&oc=1&sal=\'+sal; }\nfunction ptk(st,p) {document.cookie = \'PTK="tk=1eurcashao2i0801&type=jobsearch&subtype=\'+st+(p?\'&\'+p:\'\')+\'"; path=/\';}\nfunction rbptk(st, c, p) { ptk(st, \'cat=\'+c+(p?\'&p=\'+p:\'\'));}\n</script>\n<script type="text/javascript">\nfunction loadJSAsync( ) {\nfor ( var i = 0; i < arguments.length; i++ ) {\nvar url = arguments[i];\n(function() {\nvar s = document.createElement("script"), el = document.getElementsByTagName("script")[0];\ns.async = true;\ns.src = url;\nel.parentNode.insertBefore(s, el);\n})();\n}\n}\n</script>\n<style type="text/css">\n#resultsBody #pageContent #resultsCol .row .salarySnippet{padding-top:0.5rem}\ ...

# %% [markdown]
# ## Creating a `BeautifulSoup` object
#  - create `soup` object, then using the `find()` attribute, determine the necessary tags for desired information you want to extract from the site.

# %% [markdown]
# ### `soup.find()`

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
h1 = soup.find('h1')

# %%
type(h1)
# Out:
# bs4.element.Tag

# %%
h1.text
# Out:
# '\n            Data & Database jobs in San Francisco, CA'

# %% [markdown]
# ### `soup.find_all()`
#
# - to find out which 'div' tags we want, you can use `find_all()` to list out all possible classes in 'div'
# - using `inspect` option, you can easily narrow down which div tags contain the desired text or a block of information

# %%
h2_tags = soup.find_all('h2')

# %%
[tag.text.strip() for tag in h2_tags]
# Out:
# ['Principal Business Data Analyst\nnew',
#  'Lead Big Data Architect ( SME ) & Training lead\nnew',
#  'Data Scientist\nnew',
#  'Graduate Business Analyst\nnew',
#  'Data Engineer\nnew',
#  'Senior Data Analyst\nnew',
#  'Software Engineer II: Data Pipeline\nnew',
#  'Informatica Developer\nnew',
#  'Warranty Business Analyst\nnew',
#  'Sr. SQL Server DBA (w2 only)\nnew',
#  'Senior Statistical Programmer\nnew',
#  'Data Engineering Manager\nnew',
#  'Senior Data Engineer\nnew',
#  'Lending Technology Documents Business Analyst\nnew',
#  'Data Analyst\nnew']

# %%
div_tags = soup.find_all('div')
[tag.attrs for tag in div_tags]
# Out:
# [{'id': 'accessibilityBanner', 'role': 'navigation', 'aria-label': 'skip'},
#  {'class': ['main'], 'data-gnav-region': 'Main', 'data-reactroot': ''},
#  {'class': ['gnav-DesktopHeaderContainer']},
#  {'class': ['gnav-DesktopHeader', 'is-small-header', 'with-skip-nav']},
#  {'class': ['gnav-DesktopHeader-logo']},
#  {'class': ['gnav-Logo-icon'], 'aria-hidden': 'true'},
#  {'class': ['gnav-PageLinks']},
#  {'class': ['gnav-DesktopHeader-secondaryLinks']},
#  {'class': ['gnav-ProfileNavLinks']},
#  {'class': ['gnav-ResumeLink']},
#  {'class': ['gnav-LoggedOutAccountLink'], 'data-gnav-element-name': 'SignIn'},
#  {'class': ['gnav-VariantToggleLink-forEmployers']},
#  {'class': ['gnav-MobileHeaderContainer']},
#  {'class': ['gnav-MobileHeader', 'is-small-header'],
#   'data-gnav-region': 'Main'},
#  {'class': ['gnav-MobileHeader-logo']},
#  {'class': ['gnav-Logo-icon'], 'aria-hidden': 'true'},
#  {'class': ['gnav-MobileHeader-links']},
#  {'class': ['gnav-LoggedOutAccountLink'], 'data-gnav-element-name': 'SignIn'},
#  {'class': ['gnav-HamburgerIcon-container', 'gnav-ProfileNavLinks-link']},
#  {'tabindex': '0',
#   'role': 'button',
#   'aria-controls': 'gnav-burger-menu-nav',
#   'aria-label': 'Navigation menu',
#   'aria-expanded': 'false',
#   'class': ['gnav-NavIcon'],
#   'data-gnav-element-name': 'BurgerMenu',
#   'data-gnav-action': 'open'},
#  {'class': ['gnav-Menu-container', 'gnav-Menu-container--v1'],
#   'role': 'region',
#   'data-gnav-region': 'BurgerMenu'},
#  {'class': ['gnav-Menu-background']},
#  {'class': ['gnav-HamburgerIcon-close'],
#   'tabindex': '-1',
#   'role': 'button',
#   'aria-label': 'Close',
#   'data-gnav-element-name': 'Close',
#   'data-gnav-action': 'close'},
#  {'class': ['icl-NavigationList', 'icl-NavigationList--inline']},
#  {'class': ['icl-NavigationList-text']},
#  {'class': ['icl-NavigationList-text']},
#  {'class': ['icl-NavigationList-text']},
#  {'class': ['icl-NavigationList-text']},
#  {'class': ['icl-NavigationList', 'icl-NavigationList--inline']},
#  {'class': ['icl-NavigationList-text']},
#  {'class': ['icl-NavigationList-text']},
#  {'class': ['icl-NavigationList-subText']},
#  {'class': ['icl-NavigationList-text']},
#  {'id': 'gnav-header-end', 'tabindex': '-1'},
#  {'id': 'gnav-script-contents'},
#  {'id': 'what_container', 'class': ['jobsearch-EmbeddedLabelInput']},
#  {'style': 'width:340px'},
#  {'style': 'position:relative;z-index:2'},
#  {'id': 'what_acdiv', 'class': ['acd']},
#  {'id': 'where_container', 'class': ['jobsearch-EmbeddedLabelInput']},
#  {'style': 'width:200px'},
#  {'style': 'position:relative;z-index:2'},
#  {'id': 'acdiv', 'class': ['acd']},
#  {'style': 'margin-left:12px; display:flex;'},
#  {'class': ['seo-breadcrumbs-centered']},
#  {},
#  {'class': ['filters'], 'role': 'region', 'aria-label': 'filters'},
#  {'class': ['dd-wrapper'], 'id': 'filter-dateposted'},
#  {'class': ['dd-wrapper'], 'id': 'filter-remote'},
#  {'class': ['dd-wrapper'], 'id': 'filter-distance'},
#  {'class': ['dd-wrapper'], 'id': 'filter-salary-estimate'},
#  {'class': ['mosaic-zone'], 'id': 'mosaic-zone-salaryFilter'},
#  {'id': 'mosaic-provider-jsfe-salary',
#   'class': ['mosaic', 'mosaic-provider-jsfe-salary']},
#  {'class': ['dd-wrapper'], 'id': 'filter-job-type'},
#  {'class': ['dd-wrapper'], 'id': 'filter-location'},
#  {'class': ['dd-wrapper'], 'id': 'filter-company'},
#  {'class': ['dd-wrapper'], 'id': 'filter-experience-level'},
#  {'id': 'resultsColTopSpace'},
#  {'class': ['messageContainer']},
#  {'class': ['resultsTop']},
#  {'class': ['mosaic-zone'], 'id': 'mosaic-zone-aboveJobCards'},
#  {'id': 'mosaic-provider-serpreportjob',
#   'class': ['mosaic', 'mosaic-provider-serpreportjob']},
#  {'class': ['mosaic-reportcontent-wrapper']},
#  {'class': ['mosaic-reportcontent-content']},
#  {'id': 'resumePromo', 'data-tn-section': 'resumePromo'},
#  {'class': ['secondRow']},
#  {'class': ['serp-filters-sort-by-container']},
#  {'class': ['searchCountContainer']},
#  {'id': 'searchCount', 'class': ['searchCount-a11y-contrast-color']},
#  {'id': 'searchCountPages'},
#  {'class': ['serp-relevance-explanation']},
#  {'class': ['serp-relevance-explanation-tooltip', 'hidden'],
#   'aria-modal': 'true',
#   'role': 'dialog'},
#  {'class': ['icl-Callout', 'icl-Callout--caretEnd'],
#   'role': 'alert',
#   'aria-labelledby': 'callout-heading-1795039918'},
#  {'class': ['icl-Callout-header']},
#  {'class': ['icl-Callout-content']},
#  {'class': ['jobsearch-ResultsInfo-text']},
#  {},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'pj_9de45bbc5df33830',
#   'data-jk': '9de45bbc5df33830',
#   'data-empn': '8690912762161442',
#   'data-ci': '105245054',
#   'data-tu': 'https://jsv3.recruitics.com/partner/a51b8de1-f7bf-11e7-9edd-d951492604d9.gif?client=521&rx_c=&rx_campaign=indeed16&rx_group=100137&rx_source=Indeed&job=RS2-160649028&rx_r=none&rx_ts=20210218T234812Z&rx_pre=1&indeed=sp'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_9de45bbc5df33830',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['location', 'accessible-contrast-color-location']},
#  {'class': ['salarySnippet', 'holisticSalary']},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_0', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'id': 'jobToJobRec_9de45bbc5df33830_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'pj_58e8e4dc9e0d514e',
#   'data-jk': '58e8e4dc9e0d514e',
#   'data-empn': '8690912762161442',
#   'data-ci': '105245054',
#   'data-tu': 'https://jsv3.recruitics.com/partner/a51b8de1-f7bf-11e7-9edd-d951492604d9.gif?client=521&rx_c=&rx_campaign=indeed16&rx_group=110383&rx_source=Indeed&job=DH1-16178806&rx_r=none&rx_ts=20210218T234812Z&rx_pre=1&indeed=sp'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_58e8e4dc9e0d514e',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['location', 'accessible-contrast-color-location']},
#  {'class': ['salarySnippet', 'holisticSalary']},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_1', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'id': 'jobToJobRec_58e8e4dc9e0d514e_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'pj_062c10f43d14f5be',
#   'data-jk': '062c10f43d14f5be',
#   'data-empn': '8690912762161442',
#   'data-ci': '105245054',
#   'data-tu': 'https://jsv3.recruitics.com/partner/a51b8de1-f7bf-11e7-9edd-d951492604d9.gif?client=521&rx_c=&rx_campaign=indeed16&rx_group=110383&rx_source=Indeed&job=CV5-16198893&rx_r=none&rx_ts=20210218T234812Z&rx_pre=1&indeed=sp'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_062c10f43d14f5be',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['location', 'accessible-contrast-color-location']},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_2', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'id': 'jobToJobRec_062c10f43d14f5be_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_0506b6d88a625774',
#   'data-jk': '0506b6d88a625774',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_0506b6d88a625774',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'Oakland, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_3', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_0',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_0', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_0506b6d88a625774_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_0403fe58f2249c17',
#   'data-jk': '0403fe58f2249c17',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_0403fe58f2249c17',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_4', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_1',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_1', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_0403fe58f2249c17_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['mosaic-zone'], 'id': 'mosaic-zone-afterFifthJobResult'},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_20e116c3c9edf716',
#   'data-jk': '20e116c3c9edf716',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_20e116c3c9edf716',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_5', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_2',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_2', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_20e116c3c9edf716_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_7ab130ea8ea40fd9',
#   'data-jk': '7ab130ea8ea40fd9',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_7ab130ea8ea40fd9',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_6', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_3',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_3', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_7ab130ea8ea40fd9_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_8dadeaeeeac46ba5',
#   'data-jk': '8dadeaeeeac46ba5',
#   'data-tn-component': 'organicJob',
#   'data-tu': 'https://pixel.watch/AUvhfAyd?jz=481jn30609618CMAAKAAAAABQ&tracking-details=YmlkPTAuMDAmYmlkdHlwZT1vcmcmc3JjPUluZGVlZC1vcmdhbmljJmpJZD1hNDU0ZjQxODgzZTQxMmQxMjI2N2JkZmQzNzdmOTI0MCZlbWQ9MC4wMCZwaElkPTgxam4mZUJpZD0wLjA&indeed=organic'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_8dadeaeeeac46ba5',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_7', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_4',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_4', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_8dadeaeeeac46ba5_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'pj_0c3b7d15ee20cb6c',
#   'data-jk': '0c3b7d15ee20cb6c',
#   'data-empn': '5374313425544726',
#   'data-ci': '349134016',
#   'data-tu': 'https://d.hodes.com/i?e=se&tv=pixel_tracker&p=web&aid=facebook&se_ca=indeed&se_ac=impression&se_la=12287340&se_pr=a9ba32120d8b612d&se_va=11243&tr_af=paid&ti_id=2172_a1K2K000007oftwUAA-USCaSo25&indeed=sp'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_0c3b7d15ee20cb6c',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['location', 'accessible-contrast-color-location']},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_8', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'id': 'jobToJobRec_0c3b7d15ee20cb6c_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_155639ecf502ba22',
#   'data-jk': '155639ecf502ba22',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_155639ecf502ba22',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'South San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_9', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_5',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_5', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_155639ecf502ba22_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['mosaic-zone'], 'id': 'mosaic-zone-afterTenthJobResult'},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_376155070178d1ad',
#   'data-jk': '376155070178d1ad',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_376155070178d1ad',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_10', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_6',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_6', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_376155070178d1ad_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_7989762a843c25d3',
#   'data-jk': '7989762a843c25d3',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_7989762a843c25d3',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_11', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_7',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_7', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_7989762a843c25d3_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_8afc289ac22cb2eb',
#   'data-jk': '8afc289ac22cb2eb',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_8afc289ac22cb2eb',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'San Francisco, CA',
#   'style': 'display: none'},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_12', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_8',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_8', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_8afc289ac22cb2eb_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_7189aa59f10c0551',
#   'data-jk': '7189aa59f10c0551',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_7189aa59f10c0551',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'Berkeley, CA',
#   'style': 'display: none'},
#  {'class': ['salarySnippet', 'holisticSalary']},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_13', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_9',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_9', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_7189aa59f10c0551_sj', 'class': ['jobToJobRec_Hide']},
#  {'class': ['jobsearch-SerpJobCard', 'unifiedRow', 'row', 'result'],
#   'id': 'p_81193395dcf29d2f',
#   'data-jk': '81193395dcf29d2f',
#   'data-tn-component': 'organicJob'},
#  {'class': ['sjcl']},
#  {},
#  {'id': 'recJobLoc_81193395dcf29d2f',
#   'class': ['recJobLoc'],
#   'data-rc-loc': 'Richmond, CA',
#   'style': 'display: none'},
#  {'class': ['salarySnippet', 'holisticSalary']},
#  {'class': ['summary']},
#  {'class': ['jobsearch-SerpJobCard-footer']},
#  {'class': ['jobsearch-SerpJobCard-footerActions']},
#  {'class': ['result-link-bar-container']},
#  {'class': ['result-link-bar']},
#  {'id': 'tt_set_14', 'class': ['tt_set']},
#  {'class': ['job-reaction']},
#  {'class': ['tab-container']},
#  {'id': 'tt_display_10',
#   'class': ['more-links-container', 'result-tab'],
#   'style': 'display:none;'},
#  {'id': 'more_10', 'class': ['more_actions']},
#  {'class': ['dya-container', 'result-tab']},
#  {'class': ['tellafriend-container', 'result-tab', 'email_job_content']},
#  {'class': ['sign-in-container', 'result-tab']},
#  {'id': 'jobToJobRec_81193395dcf29d2f_sj', 'class': ['jobToJobRec_Hide']},
#  {'id': 'mosaic-provider-jobsearch-feedback',
#   'class': ['mosaic', 'mosaic-provider-jobsearch-feedback']},
#  {'class': []},
#  {'id': 'ratingForm', 'class': []},
#  {'class': ['icl-Card', 'icl-Card--hasBorder']},
#  {'class': ['icl-Card-body']},
#  {'class': ['icl-Card-cta']},
#  {'class': ['ipl-smiley-rating', 'css-vurnku', 'eu4oa1w0']},
#  {'class': ['css-18mg9wb', 'eu4oa1w0']},
#  {'class': ['animatedToast']},
#  {'id': 'gratitude', 'class': []},
#  {'class': ['pagination'], 'onmousedown': 'pclk(event);'},
#  {'class': ['mosaic-zone'], 'id': 'mosaic-zone-belowJobResultsPagination'},
#  {'id': 'mosaic-provider-jsfe-career-questions',
#   'class': ['mosaic', 'mosaic-provider-jsfe-career-questions']},
#  {'id': 'jobalertswrapper'},
#  {'id': 'jobalerts', 'class': ['open', 'jaui']},
#  {'class': ['jobalertlabel']},
#  {'id': 'jobalertlabel', 'class': ['jobalerts_title']},
#  {'id': 'jobalertform', 'class': ['jaform']},
#  {'id': 'jobalertmessage'},
#  {'id': 'invisible-hcaptcha-div', 'class': ['h-captcha']},
#  {'class': ['ja-link']},
#  {'id': 'twoPaneApplyParent'},
#  {'class': ['mosaic-zone'], 'id': 'mosaic-zone-belowPageContent'},
#  {'id': 'footerWrapper', 'style': 'text-align:center;'},
#  {'id': 'footer', 'style': 'text-align:left;'},
#  {'class': ['separator_bottom']},
#  {'class': ['gnav'], 'id': 'gnav-footer-container'},
#  {'class': ['main'], 'data-gnav-region': 'MainFooter', 'data-reactroot': ''},
#  {'class': ['icl-GlobalFooter-nav']},
#  {'id': 'resumeCtaFooter', 'style': 'height:64px;'},
#  {'style': 'position:absolute;width:100%;'},
#  {'class': ['footerCta', 'greyBar']},
#  {'id': 'thirdPartyApplyCreateAccountModal'},
#  {'id': 'successfullySignedInModal'}]

# %%
div_class_sjcl = soup.find('div', {'class': 'jobsearch-SerpJobCard'}, )
div_class_sjcl
# Out:
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="105245054" data-empn="8690912762161442" data-jk="9de45bbc5df33830" data-tu="https://jsv3.recruitics.com/partner/a51b8de1-f7bf-11e7-9edd-d951492604d9.gif?client=521&amp;rx_c=&amp;rx_campaign=indeed16&amp;rx_group=100137&amp;rx_source=Indeed&amp;job=RS2-160649028&amp;rx_r=none&amp;rx_ts=20210218T234812Z&amp;rx_pre=1&amp;indeed=sp" id="pj_9de45bbc5df33830">
# <style>
# .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}.jasxrefreshcombotst .jobcard_logo img{max-height:2rem;max-width:100%}
# </style>
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0CpFJQzrgRR8WqXWK1qKKEqALWJw739KlKqr2H-MSI4eh4ZOxqVaUrhNSyjVEAq5t5jALyjjh_OWyJDl83j5GnWTU7LTov5wyXu9VP1MwBaO1MR_FJD5HBuL4WLDLhm_4Bqkr0N_FHQNUsVFrB9JQcJrBA3b8fI2IeZIDwvEsTdQKkBTXMoFIsvndoqcXTdvd5qKpCgzkphzlNqMKhBKXD6dtZoHF8CFthOMA2eve0Tu7K7giJaY5mOy2bWs2aOH0L2oXlk90IkBB7CgDMMPZ6l6k14PDvNww_03QBONH7VzWg2OORmFtxtlgNOFJVKWHO2xGTz5DmoDp_qQPw09N0a_YRL1QHoNFGFw3lerZSfVaXjiCYwSPiNNqypOJgFmksRQuF8xm4mYA3ObssDa21CRlts4Lya49UeHKHSyjTa2_cdLquYNGsOXR7aTwKO-3qf60a7i02Q-WG23Y8VHRmIGf5ksiuCKtTlxIuE5S5JKJH1N05-YuZI8y7DquRqvhDS5Gx39PEy7JQoIw2KQUyqHKQEMp9IZiCMgnwudUM3BxrPiau_mLPTLJDOt7jit6Hx7dFQdAqEXOW2CwZyfxRCrtZkfiwvCRYnFfUjJkuu8mDY4O_zTFT2Qw_xXRmfRLWd94tlgv8DqllJwfY8m1n1osqzzyctvYjh52JPExXaWAP6IGvQ04uzwxUEod52RaBlLyPreC1-UaLoaad8MfpiPUA6ou0Ip5uIRGeHplrB-oyAjDuJ7xqhTsjGpwNLJ9dRkFSFb5sgZ3fYDSyuRGeYrb6L35Klt6CeMtIkJznDHaUlHv0yfTrifH9HpwLOVZHojMiQEwSjX2ePLhleE7EnoyFyI3R3vVZ0SlnigY-dqWoajueXi-UMI2tu9sSnoQuUhyeVWL9mSRPmeK0WiklIcAszQto4P4PSa1nMCVSwEuj-w8QGRqwE8oAvT9oBrCHcC9D6AhcshpGtS1SWVelL6rBfEIUvuUU=&amp;p=0&amp;fvj=0&amp;vjs=3" id="sja0" onclick="setRefineByCookie([]); sjoc('sja0', 1); convCtr('SJ'); rclk(this,jobmap[0],true,1);" onmousedown="sjomd('sja0'); clk('sja0'); rclk(this,jobmap[0],1);" rel="noopener nofollow" target="_blank" title="Senior Data Engineer">
# Senior <b>Data</b> Engineer</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Cybercoders" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=9de45bbc5df33830&amp;jcid=1baa5ded61092dc7')" rel="noopener" target="_blank">
# CyberCoders</a></span>
# <span class="ratingsDisplay">
# <a aria-label="Company rating 3.2 out of 5 stars" class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Cybercoders/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Senior+Data+Engineer&amp;fromjk=9de45bbc5df33830&amp;jcid=1baa5ded61092dc7');" rel="noopener" target="_blank" title="Cybercoders reviews">
# <span class="ratingsContent">
# 3.2<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_9de45bbc5df33830" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Francisco, CA 94103 <span style="font-size: smaller">(South Of Market area)</span></div>
# <span class="remote-bullet">•</span>
# <span class="remote">Remote</span>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $140,000 - $180,000 a year</span>
# </span>
# </div>
# <table class="jobCardShelfContainer" role="presentation"><tr class="jobCardShelf"><td class="jobCardShelfItem indeedApply"><span class="jobCardShelfIcon"><svg fill="none" height="16" viewbox="0 0 20 20" width="16"><rect fill="#FF5A1F" height="20" rx="10" width="20"></rect><path clip-rule="evenodd" d="M15.3125 4.0625L10.8125 15.3125L7.99999 11.375L15.3125 4.0625ZM7.604 12.7576L6.875 15.3125L8.567 14.1054L7.604 12.7576ZM7.20463 10.5796L12.419 5.36525L4.0625 9.125L6.9875 10.7968L7.20463 10.5796Z" fill="white" fill-rule="evenodd"></path></svg></span><span class="iaLabel iaIconActive">Easily apply</span></td></tr></table><div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li>In addition to rolling up your sleeves and helping to guide the <b>data</b> engineers in a hands-on capacity, you will actually influence the tech direction for the…</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">4 days ago</span><div class="tt_set" id="tt_set_0"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('9de45bbc5df33830', true, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('9de45bbc5df33830', 'save', 'linkbar', true, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, '9de45bbc5df33830', 'unsave', 'linkbar', true, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('9de45bbc5df33830');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_9de45bbc5df33830" onclick="changeJobState('9de45bbc5df33830', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></div><script>if (!window['sj_result_9de45bbc5df33830']) {window['sj_result_9de45bbc5df33830'] = {};}window['sj_result_9de45bbc5df33830']['showSource'] = false; window['sj_result_9de45bbc5df33830']['source'] = "CyberCoders"; window['sj_result_9de45bbc5df33830']['loggedIn'] = false; window['sj_result_9de45bbc5df33830']['showMyJobsLinks'] = false;window['sj_result_9de45bbc5df33830']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['sj_result_9de45bbc5df33830']['undoAction'] = "unsave";window['sj_result_9de45bbc5df33830']['relativeJobAge'] = "4 days ago";window['sj_result_9de45bbc5df33830']['jobKey'] = "9de45bbc5df33830"; window['sj_result_9de45bbc5df33830']['myIndeedAvailable'] = true; window['sj_result_9de45bbc5df33830']['showMoreActionsLink'] = window['sj_result_9de45bbc5df33830']['showMoreActionsLink'] || false; window['sj_result_9de45bbc5df33830']['resultNumber'] = 0; window['sj_result_9de45bbc5df33830']['jobStateChangedToSaved'] = false; window['sj_result_9de45bbc5df33830']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date&amp;start=80"; window['sj_result_9de45bbc5df33830']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_9de45bbc5df33830']['saveJobFailed'] = false; window['sj_result_9de45bbc5df33830']['removeJobFailed'] = false; window['sj_result_9de45bbc5df33830']['requestPending'] = false; window['sj_result_9de45bbc5df33830']['currentPage'] = "serp"; window['sj_result_9de45bbc5df33830']['sponsored'] = true;window['sj_result_9de45bbc5df33830']['reportJobButtonEnabled'] = false; window['sj_result_9de45bbc5df33830']['showMyJobsHired'] = false; window['sj_result_9de45bbc5df33830']['showSaveForSponsored'] = true; window['sj_result_9de45bbc5df33830']['showJobAge'] = true; window['sj_result_9de45bbc5df33830']['showHolisticCard'] = true; window['sj_result_9de45bbc5df33830']['showDislike'] = true; window['sj_result_9de45bbc5df33830']['showKebab'] = true; window['sj_result_9de45bbc5df33830']['showReport'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>

# %% [markdown]
# - `'class': 'jobsearch-SerpJobCard'` looks to contain the smaller blocks of information we want.
# - You can create a separate soup object for the specific class to get information from each 'job cards'

# %% [markdown]
# ## Extract relevant information
# - Once you narrow down which 'block' of class to look into, you can deduce what sub-classes you want to extract from the job card.
# - In this case, subclasses are titled intuitively, and finding title, company, location, and summary are all quite easy.

# %%
title = div_class_sjcl.find('h2', {'class': 'title'})
title.text.strip().replace('\n', '_')
# Out:
# 'Principal Business Data Analyst_new'

# %%
company = div_class_sjcl.find('span', {'class': 'company'})
company.text.strip()
# Out:
# 'CyberCoders'

# %%
ratings = div_class_sjcl.find('span', {'class': 'ratingsContent'})
ratings.text.strip()
# Out:
# '4.2'

# %%
location = div_class_sjcl.find('div', {'class': 'location'})
location.text.strip()
# Out:
# 'San Francisco, CA 94102 (Downtown area)'

# %%
summary = div_class_sjcl.find('div', {'class': 'summary'})
summary.text.strip()
# Out:
# 'In addition to rolling up your sleeves and helping to guide the data engineers in a hands-on capacity, you will actually influence the tech direction for the…'

# %%
salary = div_class_sjcl.find('div', {'class': 'salarySnippet'})
salary.text.strip()
# Out:
# '$140,000 - $180,000 a year'

# %% [markdown]
# ### Get the detailed job description using `href`
# - However, from the main search page, the job description is not fully displayed.
# - The summary section is limited to only a couple of sentences, so you need to click the link to get the full description.
# - For the individual pages, you can create new soup objects and scrape the full job description.

# %%
job_page = div_class_sjcl.find('a').attrs['href']

# %%
job_res = requests.get("http://www.indeed.com" + job_page)

# %%
job_soup = BeautifulSoup(job_res.content, 'lxml')

# %%
job_desc = job_soup.find('div', {'class':'jobsearch-jobDescriptionText'})
job_desc.text.strip().replace('\n', ' ')
# Out:
# "Overview Come join Intuit as our Data Capabilities Leader. What you'll bring7-12 years of experience working in product, marketing or other related analytics fields.Excels at organizing and tracking work, and mobilizing others to contribute to a shared visionAbility to tell stories with data, educates effectively, and instills confidence in recommendations, motivating others to act on themUnderstanding of a variety of analytics tools and technologies such as Segment and AmplitudeAbility to manage multiple projects simultaneously to meet objectives and deadlines.Outstanding communications skills with both technical and non-technical colleagues.Strong organizational skills, time management, portfolio prioritization experience, and accountability required.Attention to detail and bias to action: pursue data quality, troubleshoot data validation, and see issues to resolution How you will leadLead the strategy and vision around the technical work needed on data initiativesForm a point of view and represent analytics in evolving our data tech standards (changes to event collection standards, for example)Co-leading/representing the analytics organization in major data tool and infrastructure initiatives (Segment, AWS migration, Martech, Amplitude etc)Drive forward Intuit’s experimentation standards, infrastructure, and tools"

# %% [markdown]
# ### Put together and test if it works for other job postings
#
# - To make sure the classes and subclasses are limited to the one example above, I decided to put them together test it on a job posting.

# %%
jobcards = soup.find_all('div', {'class': 'jobsearch-SerpJobCard'})
for jobcard in jobcards:
    print(jobcard)
# Out:
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="327811381" data-empn="3018725801175434" data-jk="8c0932ee405ce4e0" data-tu="https://analytics.prng.co/i?e=se&amp;aid=indeed-firstclick&amp;p=web&amp;tv=no-js-0.1.0&amp;tna=indeed-firstclick-tracker&amp;se_ca=click&amp;se_ac=first-click&amp;se_la=jdv7vsb&amp;se_va=0.00&amp;indeed=sp" id="pj_8c0932ee405ce4e0">
# <style>
# .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}.jasxrefreshcombotst .jobcard_logo img{max-height:2rem;max-width:100%}
# </style>
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0ClvsRMZZYbWkncYKklQZhomgGvtzxN2NDL0Yep_oEtFRBSc398mSurUi9Mojk8pioLkD7-Zmd2-h3tMvU6wmDIM30sR5rTcVlpZ_fpyNY9mCGbfuxgCFWfwIGBtfL4hEIj79CikPuVi9CjiePfaXArQ4BJnaAFK_ycxF1m_7BdNU1pCCTY0gM-xyFxTwJOf17a3baB6ZnqI5IMOyJsTiVQQ4q0sYbpchcgqhR-XegJPu8ztFaOdFyD968gyOYFbc56AhSc-yemTbaRA2wzRASxlirmj1lKIFCmpD12owebrRfON-pRUUshsMuXstMyOOk-vrQ3AZ44z2F-Pht61vjNck6arvypYbj_nHfNttOzMRx_m_uYH6wB3ksLYoK6o3YJbzf2UGGkVV0Yst2zdk5MrbILY1voBCE=&amp;p=0&amp;fvj=0&amp;vjs=3" id="sja0" onclick="setRefineByCookie([]); sjoc('sja0', 0); convCtr('SJ'); rclk(this,jobmap[0],true,0);" onmousedown="sjomd('sja0'); clk('sja0'); rclk(this,jobmap[0],0);" rel="noopener nofollow" target="_blank" title="Principal Business Data Analyst">
# Principal Business <b>Data</b> Analyst</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Intuit" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=8c0932ee405ce4e0&amp;jcid=9784ae78e9834539')" rel="noopener" target="_blank">
# Intuit</a></span>
# <span class="ratingsDisplay">
# <a aria-label="Company rating 4.2 out of 5 stars" class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Intuit/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Principal+Business+Data+Analyst&amp;fromjk=8c0932ee405ce4e0&amp;jcid=9784ae78e9834539');" rel="noopener" target="_blank" title="Intuit reviews">
# <span class="ratingsContent">
# 4.2<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_8c0932ee405ce4e0" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Francisco, CA 94102 <span style="font-size: smaller">(Downtown area)</span></div>
# </div>
# <div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li>Attention to detail and bias to action: pursue <b>data</b> quality, troubleshoot <b>data</b> validation, and see issues to resolution.</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Just posted</span><div class="tt_set" id="tt_set_0"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('8c0932ee405ce4e0', true, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('8c0932ee405ce4e0', 'save', 'linkbar', true, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, '8c0932ee405ce4e0', 'unsave', 'linkbar', true, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('8c0932ee405ce4e0');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_8c0932ee405ce4e0" onclick="changeJobState('8c0932ee405ce4e0', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></div><script>if (!window['sj_result_8c0932ee405ce4e0']) {window['sj_result_8c0932ee405ce4e0'] = {};}window['sj_result_8c0932ee405ce4e0']['showSource'] = false; window['sj_result_8c0932ee405ce4e0']['source'] = "Intuit"; window['sj_result_8c0932ee405ce4e0']['loggedIn'] = false; window['sj_result_8c0932ee405ce4e0']['showMyJobsLinks'] = false;window['sj_result_8c0932ee405ce4e0']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['sj_result_8c0932ee405ce4e0']['undoAction'] = "unsave";window['sj_result_8c0932ee405ce4e0']['relativeJobAge'] = "Just posted";window['sj_result_8c0932ee405ce4e0']['jobKey'] = "8c0932ee405ce4e0"; window['sj_result_8c0932ee405ce4e0']['myIndeedAvailable'] = true; window['sj_result_8c0932ee405ce4e0']['showMoreActionsLink'] = window['sj_result_8c0932ee405ce4e0']['showMoreActionsLink'] || false; window['sj_result_8c0932ee405ce4e0']['resultNumber'] = 0; window['sj_result_8c0932ee405ce4e0']['jobStateChangedToSaved'] = false; window['sj_result_8c0932ee405ce4e0']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date"; window['sj_result_8c0932ee405ce4e0']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_8c0932ee405ce4e0']['saveJobFailed'] = false; window['sj_result_8c0932ee405ce4e0']['removeJobFailed'] = false; window['sj_result_8c0932ee405ce4e0']['requestPending'] = false; window['sj_result_8c0932ee405ce4e0']['currentPage'] = "serp"; window['sj_result_8c0932ee405ce4e0']['sponsored'] = true;window['sj_result_8c0932ee405ce4e0']['reportJobButtonEnabled'] = false; window['sj_result_8c0932ee405ce4e0']['showMyJobsHired'] = false; window['sj_result_8c0932ee405ce4e0']['showSaveForSponsored'] = true; window['sj_result_8c0932ee405ce4e0']['showJobAge'] = true; window['sj_result_8c0932ee405ce4e0']['showHolisticCard'] = true; window['sj_result_8c0932ee405ce4e0']['showDislike'] = true; window['sj_result_8c0932ee405ce4e0']['showKebab'] = true; window['sj_result_8c0932ee405ce4e0']['showReport'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="364423178" data-empn="3079575099957721" data-jk="db9e2337c7e5381f" id="pj_db9e2337c7e5381f">
# <style>
# .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}.jasxrefreshcombotst .jobcard_logo img{max-height:2rem;max-width:100%}
# </style>
# <div class="jobcard_logo">
# <a href="/cmp/Enhance-IT" onmousedown="this.href = appendParamsOnce(this.href, 'tk=1eurcashao2i0801&amp;campaignid=femp&amp;from=femp');" rel="noopener" target="_blank">
# <img alt="Enhance IT - go to company page" src="https://d2q79iu7y748jz.cloudfront.net/s/_logo/9a5cf605e02543a2017b07b0187fd7e9"/>
# </a>
# </div>
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0D3X2jYd6ThPWMa4ZMO9gBG8KguSxH4ZmHDXBhH--UKQDwMridNUkk8U36eN9uskUM2RNsB32pg4lN0VX8JCqZ1cAudoOT8U4KqG4zixSUprLxArLldS-T_FG1tJBjBsya89Nz2F6xdygcxfXiO592juyjbbTMSz8obC_5qFFa2RQCXkzmvHWafuCYC1oNZeplboc7o2MUI4X_o5Ev_t9H8Y4YZYIMtCjdhO5K0bfveXlcnGLRJW1BkOziFSwHf7HdtDvlASUqgyiuZxe7HaOfJVgVCjNLEuGdLltG5dofSo6zUCGMZVvU8eMQlKpWjAK84F7eXPsuczWeoamMJ_A6iiKrbnQN-j7cpMUMIDnGevYRmbWVeYHxWsDKkazuSwR-U1R02cqEaXquQ77RSzYqWNfu42Hae37nKeHaXNeuYSs5aPYo1wMSAMWQunXIC4Gj5RUYuA4568B98lRctPzGf57_Hlnji-Plpg0peylcM3sZjNyqymtVU-uTs10cEjqw=&amp;p=1&amp;fvj=1&amp;vjs=3" id="sja1" onclick="setRefineByCookie([]); sjoc('sja1', 1); convCtr('SJ'); rclk(this,jobmap[1],true,1);" onmousedown="sjomd('sja1'); clk('sja1'); rclk(this,jobmap[1],1);" rel="noopener nofollow" target="_blank" title="Lead Big Data Architect ( SME ) &amp; Training lead">
# Lead Big <b>Data</b> Architect ( SME ) &amp; Training lead</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Enhance-IT" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=db9e2337c7e5381f&amp;jcid=4c8d1f66feb023d6')" rel="noopener" target="_blank">
# Enhance IT</a></span>
# <span class="ratingsDisplay">
# <a aria-label="Company rating 3.1 out of 5 stars" class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Enhance-IT/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Lead+Big+Data+Architect+%28+SME+%29+%26+Training+lead&amp;fromjk=db9e2337c7e5381f&amp;jcid=4c8d1f66feb023d6');" rel="noopener" target="_blank" title="Enhance IT reviews">
# <span class="ratingsContent">
# 3.1<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="California" id="recJobLoc_db9e2337c7e5381f" style="display: none"></div>
# <div class="location accessible-contrast-color-location">California</div>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $100,000 - $120,000 a year</span>
# </span>
# </div>
# <table class="jobCardShelfContainer" role="presentation"><tr class="jobCardShelf"><td class="jobCardShelfItem indeedApply"><span class="jobCardShelfIcon"><svg fill="none" height="16" viewbox="0 0 20 20" width="16"><rect fill="#FF5A1F" height="20" rx="10" width="20"></rect><path clip-rule="evenodd" d="M15.3125 4.0625L10.8125 15.3125L7.99999 11.375L15.3125 4.0625ZM7.604 12.7576L6.875 15.3125L8.567 14.1054L7.604 12.7576ZM7.20463 10.5796L12.419 5.36525L4.0625 9.125L6.9875 10.7968L7.20463 10.5796Z" fill="white" fill-rule="evenodd"></path></svg></span><span class="iaLabel iaIconActive">Easily apply</span></td></tr></table><div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li style="margin-bottom:0px;">Good knowledge of <b>database</b> structures, theories, principles and practices.</li>
# <li>Translate complex functional and technical requirements into detail design…</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Just posted</span><div class="tt_set" id="tt_set_1"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('db9e2337c7e5381f', true, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('db9e2337c7e5381f', 'save', 'linkbar', true, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, 'db9e2337c7e5381f', 'unsave', 'linkbar', true, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('db9e2337c7e5381f');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_db9e2337c7e5381f" onclick="changeJobState('db9e2337c7e5381f', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></div><script>if (!window['sj_result_db9e2337c7e5381f']) {window['sj_result_db9e2337c7e5381f'] = {};}window['sj_result_db9e2337c7e5381f']['showSource'] = false; window['sj_result_db9e2337c7e5381f']['source'] = "Indeed"; window['sj_result_db9e2337c7e5381f']['loggedIn'] = false; window['sj_result_db9e2337c7e5381f']['showMyJobsLinks'] = false;window['sj_result_db9e2337c7e5381f']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['sj_result_db9e2337c7e5381f']['undoAction'] = "unsave";window['sj_result_db9e2337c7e5381f']['relativeJobAge'] = "Just posted";window['sj_result_db9e2337c7e5381f']['jobKey'] = "db9e2337c7e5381f"; window['sj_result_db9e2337c7e5381f']['myIndeedAvailable'] = true; window['sj_result_db9e2337c7e5381f']['showMoreActionsLink'] = window['sj_result_db9e2337c7e5381f']['showMoreActionsLink'] || false; window['sj_result_db9e2337c7e5381f']['resultNumber'] = 1; window['sj_result_db9e2337c7e5381f']['jobStateChangedToSaved'] = false; window['sj_result_db9e2337c7e5381f']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date"; window['sj_result_db9e2337c7e5381f']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_db9e2337c7e5381f']['saveJobFailed'] = false; window['sj_result_db9e2337c7e5381f']['removeJobFailed'] = false; window['sj_result_db9e2337c7e5381f']['requestPending'] = false; window['sj_result_db9e2337c7e5381f']['currentPage'] = "serp"; window['sj_result_db9e2337c7e5381f']['sponsored'] = true;window['sj_result_db9e2337c7e5381f']['reportJobButtonEnabled'] = false; window['sj_result_db9e2337c7e5381f']['showMyJobsHired'] = false; window['sj_result_db9e2337c7e5381f']['showSaveForSponsored'] = true; window['sj_result_db9e2337c7e5381f']['showJobAge'] = true; window['sj_result_db9e2337c7e5381f']['showHolisticCard'] = true; window['sj_result_db9e2337c7e5381f']['showDislike'] = true; window['sj_result_db9e2337c7e5381f']['showKebab'] = true; window['sj_result_db9e2337c7e5381f']['showReport'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="9cd3bf00749a793f" data-tn-component="organicJob" id="p_9cd3bf00749a793f">
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=9cd3bf00749a793f&amp;fccid=d28b18be62aeef28&amp;vjs=3" id="jl_9cd3bf00749a793f" onclick="setRefineByCookie([]); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="noopener nofollow" target="_blank" title="Data Scientist">
# <b>Data</b> Scientist</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# Extend</span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_9cd3bf00749a793f" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA</span>
# <span class="remote-bullet">•</span>
# <span class="remote">Remote</span>
# </div>
# <div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li>Work with <b>data</b> engineering and product teams to ensure proper <b>data</b> tracking is set up for features and products, and support debugging and development of new…</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Just posted</span><div class="tt_set" id="tt_set_2"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('9cd3bf00749a793f', false, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('9cd3bf00749a793f', 'save', 'linkbar', false, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, '9cd3bf00749a793f', 'unsave', 'linkbar', false, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('9cd3bf00749a793f');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_9cd3bf00749a793f" onclick="changeJobState('9cd3bf00749a793f', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more-link" id="tog_2" onclick="toggleMoreLinks('9cd3bf00749a793f', '2'); return false;">More...</button></div><script>if (!window['result_9cd3bf00749a793f']) {window['result_9cd3bf00749a793f'] = {};}window['result_9cd3bf00749a793f']['showSource'] = false; window['result_9cd3bf00749a793f']['source'] = "Extend"; window['result_9cd3bf00749a793f']['loggedIn'] = false; window['result_9cd3bf00749a793f']['showMyJobsLinks'] = false;window['result_9cd3bf00749a793f']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['result_9cd3bf00749a793f']['undoAction'] = "unsave";window['result_9cd3bf00749a793f']['relativeJobAge'] = "Just posted";window['result_9cd3bf00749a793f']['jobKey'] = "9cd3bf00749a793f"; window['result_9cd3bf00749a793f']['myIndeedAvailable'] = true; window['result_9cd3bf00749a793f']['showMoreActionsLink'] = window['result_9cd3bf00749a793f']['showMoreActionsLink'] || true; window['result_9cd3bf00749a793f']['resultNumber'] = 2; window['result_9cd3bf00749a793f']['jobStateChangedToSaved'] = false; window['result_9cd3bf00749a793f']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date"; window['result_9cd3bf00749a793f']['basicPermaLink'] = "https://www.indeed.com"; window['result_9cd3bf00749a793f']['saveJobFailed'] = false; window['result_9cd3bf00749a793f']['removeJobFailed'] = false; window['result_9cd3bf00749a793f']['requestPending'] = false; window['result_9cd3bf00749a793f']['currentPage'] = "serp"; window['result_9cd3bf00749a793f']['sponsored'] = false;window['result_9cd3bf00749a793f']['reportJobButtonEnabled'] = false; window['result_9cd3bf00749a793f']['showMyJobsHired'] = false; window['result_9cd3bf00749a793f']['showSaveForSponsored'] = false; window['result_9cd3bf00749a793f']['showJobAge'] = true; window['result_9cd3bf00749a793f']['showHolisticCard'] = true; window['result_9cd3bf00749a793f']['showDislike'] = true; window['result_9cd3bf00749a793f']['showKebab'] = true; window['result_9cd3bf00749a793f']['showReport'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_0" style="display:none;"><div class="more_actions" id="more_0"><ul><li><span class="mat">View all <a href="/q-Extend-l-San-Francisco,-CA-jobs.html">Extend jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/data-scientist-Salaries,-San-Francisco-CA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=9cd3bf00749a793f&amp;from=serp-more');">Data Scientist salaries in San Francisco, CA</a></span></li><li><span class="mat">Explore career as Data Scientist: <a href="/career/data-scientist" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">overview</a>, <a href="/career/data-scientist/career-advice" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">career advice</a>, <a href="/career/data-scientist/faq" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">FAQs</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('9cd3bf00749a793f'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# </div>
# </div>
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="52ded3d1e30ebd8f" data-tn-component="organicJob" id="p_52ded3d1e30ebd8f">
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=52ded3d1e30ebd8f&amp;fccid=e1bd9b04e60a54d5&amp;vjs=3" id="jl_52ded3d1e30ebd8f" onclick="setRefineByCookie([]); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="noopener nofollow" target="_blank" title="Graduate Business Analyst">
# Graduate Business Analyst</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# Arbor Financial Systems</span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco Bay Area, CA" id="recJobLoc_52ded3d1e30ebd8f" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco Bay Area, CA</span>
# </div>
# <div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li>The role is for a trainee business analyst to work closely with clients (hedge funds and brokers) on understanding their business requirements plus managing…</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Just posted</span><div class="tt_set" id="tt_set_3"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('52ded3d1e30ebd8f', false, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('52ded3d1e30ebd8f', 'save', 'linkbar', false, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, '52ded3d1e30ebd8f', 'unsave', 'linkbar', false, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('52ded3d1e30ebd8f');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_52ded3d1e30ebd8f" onclick="changeJobState('52ded3d1e30ebd8f', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more-link" id="tog_3" onclick="toggleMoreLinks('52ded3d1e30ebd8f', '3'); return false;">More...</button></div><script>if (!window['result_52ded3d1e30ebd8f']) {window['result_52ded3d1e30ebd8f'] = {};}window['result_52ded3d1e30ebd8f']['showSource'] = false; window['result_52ded3d1e30ebd8f']['source'] = "Arbor Financial Systems"; window['result_52ded3d1e30ebd8f']['loggedIn'] = false; window['result_52ded3d1e30ebd8f']['showMyJobsLinks'] = false;window['result_52ded3d1e30ebd8f']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['result_52ded3d1e30ebd8f']['undoAction'] = "unsave";window['result_52ded3d1e30ebd8f']['relativeJobAge'] = "Just posted";window['result_52ded3d1e30ebd8f']['jobKey'] = "52ded3d1e30ebd8f"; window['result_52ded3d1e30ebd8f']['myIndeedAvailable'] = true; window['result_52ded3d1e30ebd8f']['showMoreActionsLink'] = window['result_52ded3d1e30ebd8f']['showMoreActionsLink'] || true; window['result_52ded3d1e30ebd8f']['resultNumber'] = 3; window['result_52ded3d1e30ebd8f']['jobStateChangedToSaved'] = false; window['result_52ded3d1e30ebd8f']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date"; window['result_52ded3d1e30ebd8f']['basicPermaLink'] = "https://www.indeed.com"; window['result_52ded3d1e30ebd8f']['saveJobFailed'] = false; window['result_52ded3d1e30ebd8f']['removeJobFailed'] = false; window['result_52ded3d1e30ebd8f']['requestPending'] = false; window['result_52ded3d1e30ebd8f']['currentPage'] = "serp"; window['result_52ded3d1e30ebd8f']['sponsored'] = false;window['result_52ded3d1e30ebd8f']['reportJobButtonEnabled'] = false; window['result_52ded3d1e30ebd8f']['showMyJobsHired'] = false; window['result_52ded3d1e30ebd8f']['showSaveForSponsored'] = false; window['result_52ded3d1e30ebd8f']['showJobAge'] = true; window['result_52ded3d1e30ebd8f']['showHolisticCard'] = true; window['result_52ded3d1e30ebd8f']['showDislike'] = true; window['result_52ded3d1e30ebd8f']['showKebab'] = true; window['result_52ded3d1e30ebd8f']['showReport'] = true;</script></div>< ...
# </div>
# </div>
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_1" style="display:none;"><div class="more_actions" id="more_1"><ul><li><span class="mat">View all <a href="/q-Arbor-Financial-Systems-l-San-Francisco-Bay-Area,-CA-jobs.html">Arbor Financial Systems jobs in San Francisco Bay Area, CA</a> - <a href="/l-San-Francisco-Bay-Area,-CA-jobs.html">San Francisco Bay Area jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/business-analyst-Salaries,-San-Francisco-Bay-Area-CA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=52ded3d1e30ebd8f&amp;from=serp-more');">Business Analyst salaries in San Francisco Bay Area, CA</a></span></li><li><span class="mat">Explore career as Business Analyst: <a href="/career/business-analyst" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">overview</a>, <a href="/career/business-analyst/career-advice" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">career advice</a>, <a href="/career/business-analyst/faq" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">FAQs</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('52ded3d1e30ebd8f'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# </div>
# </div>
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="105245054" data-empn="8690912762161442" data-jk="c97d569191587114" data-tu="https://jsv3.recruitics.com/partner/a51b8de1-f7bf-11e7-9edd-d951492604d9.gif?client=521&amp;rx_c=&amp;rx_campaign=indeed16&amp;rx_group=100137&amp;rx_source=Indeed&amp;job=TB10-16177087&amp;rx_r=none&amp;rx_ts=20210218T175318Z&amp;rx_pre=1&amp;indeed=sp" id="pj_c97d569191587114">
# <style>
# .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}.jasxrefreshcombotst .jobcard_logo img{max-height:2rem;max-width:100%}
# </style>
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0CpFJQzrgRR8WqXWK1qKKEqALWJw739KlKqr2H-MSI4eh4ZOxqVaUrhNSyjVEAq5t6LI1JbVCx5xVrhyVrStCABcICAB_KrfU3VVttIxylKPHGGcJF8i8UwNqgcI2PPuXZtsl0g9iBjcJNZt7c_TyNJxdQPAFxuYJ9z4JjvVKhVO5uqGJDeDoiBF1mnAvSZFNf0S0h_3Sr72BLEOaz-RcI4bgFf_Mtr2yHctFMGZ-Gy5ImALcurHC5pQmlIQC2hdr6_PgXwU2kEQawJMWA07iNAcg0wPqJBVAGgFI1FUtqITExizyrcLQdsSyGfbECboUAeuj1VHzqcP90wDEvcd6NI-upmJmym2R-EOljT1XoTUE-Edpk-F_ZKQg9O3OEVezg-a6SMEcV_nVic1w7rxUOxd2M2W0dHlshSbz1dGaxvGbAFxRtCE-AnuKiIXJorfFgQw34eLMjTpWoSafNij5KstdXrcdC7QHzXOv6ScR99LShLJFq37kTRBn1gioMtLN8u9rublfZo39qyx8E7yJYJ8-I6KfhJfzl86qZJFgoyHX4MQ2pbTPpyotwBYdJi7tvg8U4LMogy_Q_UiRMv0A5hO9g_UGWcc5f2jshRq7M3iNBJBVyf8jQymWgbbEY_yV_ZPw6LgvkgXGsfatjSUxdZa_8TOP_NxGf5PpJhfS3OWQRCYfi1SFTdOWL3fOJktR4dU520Pvmg7qYWuH8CUjfPM4vX9_qI3i6BMtivaDpflYkfGBC4kGQqNCReYjQ681Dnu9uUdhFYqa1K6yfMbTzgoOcEszRr5FL1gaJiXiForUEzf8w40YY9u4KyQ4Z-oQy6Yv2RhIM4U4Qy4axpgw4JlexHNzpVlQZ_izXv1jn5QR0Cr6vU0_Hve4idi_CiECSnPd9SqtbV29h5qKK7RnpIg9_969BqexGEfZvWKVuzYsIYYPSSXCJcyuog3XMfmPxkfox9qCEwDUqAJKZuRvCPaZDUXqnh8B86_lsAGjuhkw==&amp;p=4&amp;fvj=0&amp;vjs=3" id="sja4" onclick="setRefineByCookie([]); sjoc('sja4', 1); convCtr('SJ'); rclk(this,jobmap[4],true,1);" onmousedown="sjomd('sja4'); clk('sja4'); rclk(this,jobmap[4],1);" rel="noopener nofollow" target="_blank" title="Data Engineer">
# <b>Data</b> Engineer</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Cybercoders" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=c97d569191587114&amp;jcid=1baa5ded61092dc7')" rel="noopener" target="_blank">
# CyberCoders</a></span>
# <span class="ratingsDisplay">
# <a aria-label="Company rating 3.2 out of 5 stars" class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Cybercoders/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Engineer&amp;fromjk=c97d569191587114&amp;jcid=1baa5ded61092dc7');" rel="noopener" target="_blank" title="Cybercoders reviews">
# <span class="ratingsContent">
# 3.2<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Mateo, CA" id="recJobLoc_c97d569191587114" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Mateo, CA 94402 <span style="font-size: smaller">(Beresford area)</span></div>
# <span class="remote-bullet">•</span>
# <span class="remote">Remote</span>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $150,000 - $170,000 a year</span>
# </span>
# </div>
# <table class="jobCardShelfContainer" role="presentation"><tr class="jobCardShelf"><td class="jobCardShelfItem indeedApply"><span class="jobCardShelfIcon"><svg fill="none" height="16" viewbox="0 0 20 20" width="16"><rect fill="#FF5A1F" height="20" rx="10" width="20"></rect><path clip-rule="evenodd" d="M15.3125 4.0625L10.8125 15.3125L7.99999 11.375L15.3125 4.0625ZM7.604 12.7576L6.875 15.3125L8.567 14.1054L7.604 12.7576ZM7.20463 10.5796L12.419 5.36525L4.0625 9.125L6.9875 10.7968L7.20463 10.5796Z" fill="white" fill-rule="evenodd"></path></svg></span><span class="iaLabel iaIconActive">Easily apply</span></td></tr></table><div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li style="margin-bottom:0px;">5+ years of SQL <b>database</b> experience.</li>
# <li style="margin-bottom:0px;">Build scalable pipelines capable of processing massive amounts of data.</li>
# <li>Job Duration: Full-time, Direct Hire.</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Just posted</span><div class="tt_set" id="tt_set_4"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('c97d569191587114', true, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('c97d569191587114', 'save', 'linkbar', true, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, 'c97d569191587114', 'unsave', 'linkbar', true, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('c97d569191587114');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_c97d569191587114" onclick="changeJobState('c97d569191587114', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></div><script>if (!window['sj_result_c97d569191587114']) {window['sj_result_c97d569191587114'] = {};}window['sj_result_c97d569191587114']['showSource'] = false; window['sj_result_c97d569191587114']['source'] = "CyberCoders"; window['sj_result_c97d569191587114']['loggedIn'] = false; window['sj_result_c97d569191587114']['showMyJobsLinks'] = false;window['sj_result_c97d569191587114']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['sj_result_c97d569191587114']['undoAction'] = "unsave";window['sj_result_c97d569191587114']['relativeJobAge'] = "Just posted";window['sj_result_c97d569191587114']['jobKey'] = "c97d569191587114"; window['sj_result_c97d569191587114']['myIndeedAvailable'] = true; window['sj_result_c97d569191587114']['showMoreActionsLink'] = window['sj_result_c97d569191587114']['showMoreActionsLink'] || false; window['sj_result_c97d569191587114']['resultNumber'] = 4; window['sj_result_c97d569191587114']['jobStateChangedToSaved'] = false; window['sj_result_c97d569191587114']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date"; window['sj_result_c97d569191587114']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_c97d569191587114']['saveJobFailed'] = false; window['sj_result_c97d569191587114']['removeJobFailed'] = false; window['sj_result_c97d569191587114']['requestPending'] = false; window['sj_result_c97d569191587114']['currentPage'] = "serp"; window['sj_result_c97d569191587114']['sponsored'] = true;window['sj_result_c97d569191587114']['reportJobButtonEnabled'] = false; window['sj_result_c97d569191587114']['showMyJobsHired'] = false; window['sj_result_c97d569191587114']['showSaveForSponsored'] = true; window['sj_result_c97d569191587114']['showJobAge'] = true; window['sj_result_c97d569191587114']['showHolisticCard'] = true; window['sj_result_c97d569191587114']['showDislike'] = true; window['sj_result_c97d569191587114']['showKebab'] = true; window['sj_result_c97d569191587114']['showReport'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="10c718f51325d613" data-tn-component="organicJob" id="p_10c718f51325d613">
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/Arkoya/jobs/Senior-Data-Analyst-10c718f51325d613?fccid=e9f0bf69ce0f0529&amp;vjs=3" id="jl_10c718f51325d613" onclick="setRefineByCookie([]); return rclk(this,jobmap[5],true,1);" onmousedown="return rclk(this,jobmap[5],1);" rel="noopener nofollow" target="_blank" title="Senior Data Analyst">
# Senior <b>Data</b> Analyst</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# IT Strategies Inc</span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_10c718f51325d613" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA</span>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $65 - $70 an hour</span>
# </span>
# </div>
# <table class="jobCardShelfContainer" role="presentation"><tr class="jobCardShelf"><td class="jobCardShelfItem indeedApply"><span class="jobCardShelfIcon"><svg fill="none" height="16" viewbox="0 0 20 20" width="16"><rect fill="#FF5A1F" height="20" rx="10" width="20"></rect><path clip-rule="evenodd" d="M15.3125 4.0625L10.8125 15.3125L7.99999 11.375L15.3125 4.0625ZM7.604 12.7576L6.875 15.3125L8.567 14.1054L7.604 12.7576ZM7.20463 10.5796L12.419 5.36525L4.0625 9.125L6.9875 10.7968L7.20463 10.5796Z" fill="white" fill-rule="evenodd"></path></svg></span><span class="iaLabel iaIconActive">Easily apply</span></td></tr></table><div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li style="margin-bottom:0px;">5+ years of relevant experience in <b>data</b> analysis and/or <b>data</b> management.</li>
# <li>Please make sure the candidate has banking experience in loans and deposits, data…</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Just posted</span><div class="tt_set" id="tt_set_5"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('10c718f51325d613', false, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('10c718f51325d613', 'save', 'linkbar', false, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, '10c718f51325d613', 'unsave', 'linkbar', false, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('10c718f51325d613');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_10c718f51325d613" onclick="changeJobState('10c718f51325d613', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more-link" id="tog_5" onclick="toggleMoreLinks('10c718f51325d613', '5'); return false;">More...</button></div><script>if (!window['result_10c718f51325d613']) {window['result_10c718f51325d613'] = {};}window['result_10c718f51325d613']['showSource'] = false; window['result_10c718f51325d613']['source'] = "Indeed"; window['result_10c718f51325d613']['loggedIn'] = false; window['result_10c718f51325d613']['showMyJobsLinks'] = false;window['result_10c718f51325d613']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['result_10c718f51325d613']['undoAction'] = "unsave";window['result_10c718f51325d613']['relativeJobAge'] = "Just posted";window['result_10c718f51325d613']['jobKey'] = "10c718f51325d613"; window['result_10c718f51325d613']['myIndeedAvailable'] = true; window['result_10c718f51325d613']['showMoreActionsLink'] = window['result_10c718f51325d613']['showMoreActionsLink'] || true; window['result_10c718f51325d613']['resultNumber'] = 5; window['result_10c718f51325d613']['jobStateChangedToSaved'] = false; window['result_10c718f51325d613']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date"; window['result_10c718f51325d613']['basicPermaLink'] = "https://www.indeed.com"; window['result_10c718f51325d613']['saveJobFailed'] = false; window['result_10c718f51325d613']['removeJobFailed'] = false; window['result_10c718f51325d613']['requestPending'] = false; window['result_10c718f51325d613']['currentPage'] = "serp"; window['result_10c718f51325d613']['sponsored'] = false;window['result_10c718f51325d613']['reportJobButtonEnabled'] = false; window['result_10c718f51325d613']['showMyJobsHired'] = false; window['result_10c718f51325d613']['showSaveForSponsored'] = false; window['result_10c718f51325d613']['showJobAge'] = true; window['result_10c718f51325d613']['showHolisticCard'] = true; window['result_10c718f51325d613']['showDislike'] = true; window['result_10c718f51325d613']['showKebab'] = true; window['result_10c718f51325d613']['showReport'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_2" style="display:none;"><div class="more_actions" id="more_2"><ul><li><span class="mat">View all <a href="/jobs?q=IT+Strategies+Inc&amp;l=San+Francisco,+CA&amp;nc=jasx">IT Strategies Inc jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/senior-data-analyst-Salaries,-San-Francisco-CA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=10c718f51325d613&amp;from=serp-more');">Senior Data Analyst salaries in San Francisco, CA</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('10c718f51325d613'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# </div>
# </div>
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="e05f0e0ee8d7957f" data-tn-component="organicJob" id="p_e05f0e0ee8d7957f">
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=e05f0e0ee8d7957f&amp;fccid=230117385c78571f&amp;vjs=3" id="jl_e05f0e0ee8d7957f" onclick="setRefineByCookie([]); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="noopener nofollow" target="_blank" title="Software Engineer II: Data Pipeline">
# Software Engineer II: <b>Data</b> Pipeline</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Rapid7" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=e05f0e0ee8d7957f&amp;jcid=230117385c78571f')" rel="noopener" target="_blank">
# Rapid7</a></span>
# <span class="ratingsDisplay">
# <a aria-label="Company rating 3.9 out of 5 stars" class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Rapid7/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Software+Engineer+II%3A+Data+Pipeline&amp;fromjk=e05f0e0ee8d7957f&amp;jcid=230117385c78571f');" rel="noopener" target="_blank">
# <span class="ratingsContent">
# 3.9<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_e05f0e0ee8d7957f" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA 94107 <span style="font-size: smaller">(Yerba Buena area)</span></span>
# </div>
# <div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li style="margin-bottom:0px;">This includes <b>data</b> collection, and outbound <b>data</b> transfer.</li>
# <li style="margin-bottom:0px;">Experience with data/workflow engines a plus.</li>
# <li>Excellent understanding of distributed <b>data</b> streaming…</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# ...
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# </div>
# </div>
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="b09ee39cbccac27d" data-tn-component="organicJob" id="p_b09ee39cbccac27d">
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=b09ee39cbccac27d&amp;fccid=e228a3c78d0f7f13&amp;vjs=3" id="jl_b09ee39cbccac27d" onclick="setRefineByCookie([]); return rclk(this,jobmap[13],true,0);" onmousedown="return rclk(this,jobmap[13],0);" rel="noopener nofollow" target="_blank" title="Lending Technology Documents Business Analyst">
# Lending Technology Documents Business Analyst</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/First-Republic-Bank" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=b09ee39cbccac27d&amp;jcid=e228a3c78d0f7f13')" rel="noopener" target="_blank">
# First Republic Bank</a></span>
# <span class="ratingsDisplay">
# <a aria-label="Company rating 3.9 out of 5 stars" class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/First-Republic-Bank/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Lending+Technology+Documents+Business+Analyst&amp;fromjk=b09ee39cbccac27d&amp;jcid=e228a3c78d0f7f13');" rel="noopener" target="_blank" title="First Republic Bank reviews">
# <span class="ratingsContent">
# 3.9<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_b09ee39cbccac27d" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA 94111 <span style="font-size: smaller">(Financial District area)</span></span>
# </div>
# <div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li style="margin-bottom:0px;">Maintain current inventory of all upfront, interim and closing documents and their <b>data</b> elements.</li>
# <li>Must be able to review and analyze <b>data</b> reports and manuals;…</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Today</span><div class="tt_set" id="tt_set_13"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('b09ee39cbccac27d', false, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('b09ee39cbccac27d', 'save', 'linkbar', false, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, 'b09ee39cbccac27d', 'unsave', 'linkbar', false, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('b09ee39cbccac27d');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_b09ee39cbccac27d" onclick="changeJobState('b09ee39cbccac27d', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more-link" id="tog_13" onclick="toggleMoreLinks('b09ee39cbccac27d', '13'); return false;">More...</button></div><script>if (!window['result_b09ee39cbccac27d']) {window['result_b09ee39cbccac27d'] = {};}window['result_b09ee39cbccac27d']['showSource'] = false; window['result_b09ee39cbccac27d']['source'] = "First Republic Bank"; window['result_b09ee39cbccac27d']['loggedIn'] = false; window['result_b09ee39cbccac27d']['showMyJobsLinks'] = false;window['result_b09ee39cbccac27d']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['result_b09ee39cbccac27d']['undoAction'] = "unsave";window['result_b09ee39cbccac27d']['relativeJobAge'] = "Today";window['result_b09ee39cbccac27d']['jobKey'] = "b09ee39cbccac27d"; window['result_b09ee39cbccac27d']['myIndeedAvailable'] = true; window['result_b09ee39cbccac27d']['showMoreActionsLink'] = window['result_b09ee39cbccac27d']['showMoreActionsLink'] || true; window['result_b09ee39cbccac27d']['resultNumber'] = 13; window['result_b09ee39cbccac27d']['jobStateChangedToSaved'] = false; window['result_b09ee39cbccac27d']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date"; window['result_b09ee39cbccac27d']['basicPermaLink'] = "https://www.indeed.com"; window['result_b09ee39cbccac27d']['saveJobFailed'] = false; window['result_b09ee39cbccac27d']['removeJobFailed'] = false; window['result_b09ee39cbccac27d']['requestPending'] = false; window['result_b09ee39cbccac27d']['currentPage'] = "serp"; window['result_b09ee39cbccac27d']['sponsored'] = false;window['result_b09ee39cbccac27d']['reportJobButtonEnabled'] = false; window['result_b09ee39cbccac27d']['showMyJobsHired'] = false; window['result_b09ee39cbccac27d']['showSaveForSponsored'] = false; window['result_b09ee39cbccac27d']['showJobAge'] = true; window['result_b09ee39cbccac27d']['showHolisticCard'] = true; window['result_b09ee39cbccac27d']['showDislike'] = true; window['result_b09ee39cbccac27d']['showKebab'] = true; window['result_b09ee39cbccac27d']['showReport'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_10" style="display:none;"><div class="more_actions" id="more_10"><ul><li><span class="mat">View all <a href="/q-First-Republic-Bank-l-San-Francisco,-CA-jobs.html">First Republic Bank jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/First-Republic-Bank" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=b09ee39cbccac27d&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=e228a3c78d0f7f13');">First Republic Bank</a></span></li><li><span class="mat">See popular <a href="/cmp/First-Republic-Bank/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=b09ee39cbccac27d&amp;jcid=e228a3c78d0f7f13');">questions &amp; answers about First Republic Bank</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('b09ee39cbccac27d'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# </div>
# </div>
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="201569542" data-empn="4036797272231115" data-jk="e53eebb9ebb0a096" id="pj_e53eebb9ebb0a096">
# <style>
# .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}.jasxrefreshcombotst .jobcard_logo img{max-height:2rem;max-width:100%}
# </style>
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0B5eA6Qw11BI3zueTkb7RvZLDHEiPQEsT3B8y-v11rxzd9C9hhFo5Vx4yA_IOauB-JlcZoZFKL1iIijzoh2bNsE7RXM-adFhhbvsjm49jpflhBPy3BxPWyLEzMEDn8GzGWuMrIThqL5f7GUIyy8Vth-u_7NGz1utBBzDkAy4nm1cgFXqLo8lSp5yDtsGsJEjvV3fbbUpOpPwAI4E84_tTiJERVUeMG-Ype_aXyjB1ATKcYOwcEY3AY7ppfCFyZPcSBtaMqPqmfkED3F-PRy60rx6kEiLx9MTkEo6q9ukkYTx7teu1JurxSkc1oMUhh9SFD0SIQ_JH-GYyBZdY8VMi5PNFprnN-BB0mGAGHNiEdWmXJkwonpeNqISQFnIH1U13mnn4QHAQv_b8SV3LkcYrjpJjBn66WKfNWgaJ-8DXGwmNizzAJU6fufuOMwd7yCTwwXxP9fKG48Ex0J2d9RCPZ3ATvaZrO5JS-uqT_nnlP5XNjPnngZjTHC&amp;p=14&amp;fvj=0&amp;vjs=3" id="sja14" onclick="setRefineByCookie([]); sjoc('sja14', 0); convCtr('SJ'); rclk(this,jobmap[14],true,0);" onmousedown="sjomd('sja14'); clk('sja14'); rclk(this,jobmap[14],0);" rel="noopener nofollow" target="_blank" title="Data Analyst">
# <b>Data</b> Analyst</a>
# <span class="new">new</span></h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Aureus-Group" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=e53eebb9ebb0a096&amp;jcid=9595c7769dce048e')" rel="noopener" target="_blank">
# Aureus Group</a></span>
# <span class="ratingsDisplay">
# <a aria-label="Company rating 3.7 out of 5 stars" class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Aureus-Group/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Analyst&amp;fromjk=e53eebb9ebb0a096&amp;jcid=9595c7769dce048e');" rel="noopener" target="_blank" title="Aureus Group reviews">
# <span class="ratingsContent">
# 3.7<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="Oakland, CA" id="recJobLoc_e53eebb9ebb0a096" style="display: none"></div>
# <div class="location accessible-contrast-color-location">Oakland, CA</div>
# </div>
# <div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# <li style="margin-bottom:0px;">1-2yrs of <b>data</b> experience (if you have a Master’s Degree).</li>
# <li>Our client needs a <b>Data</b> Analyst with a medical claims background to support their growing not-for…</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Today</span><div class="tt_set" id="tt_set_14"><div class="job-reaction"><button aria-expanded="false" aria-haspopup="true" aria-label="save or dislike" class="job-reaction-kebab" data-ol-has-click-handler="" onclick="toggleKebabMenu('e53eebb9ebb0a096', true, event); return false;" tabindex="0"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" data-ol-has-click-handler="" onclick="changeJobState('e53eebb9ebb0a096', 'save', 'linkbar', true, '');return false;"><svg focusable="false" height="16" viewbox="0 0 24 24" width="16"><g><path d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z" fill="#2d2d2d"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" data-ol-has-click-handler="" onclick="dislikeJob(false, false, 'e53eebb9ebb0a096', 'unsave', 'linkbar', true, '');"><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('e53eebb9ebb0a096');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_e53eebb9ebb0a096" onclick="changeJobState('e53eebb9ebb0a096', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></div><script>if (!window['sj_result_e53eebb9ebb0a096']) {window['sj_result_e53eebb9ebb0a096'] = {};}window['sj_result_e53eebb9ebb0a096']['showSource'] = false; window['sj_result_e53eebb9ebb0a096']['source'] = "C\x26A Industries, Inc"; window['sj_result_e53eebb9ebb0a096']['loggedIn'] = false; window['sj_result_e53eebb9ebb0a096']['showMyJobsLinks'] = false;window['sj_result_e53eebb9ebb0a096']['baseMyJobsUrl'] = "https://myjobs.indeed.com";window['sj_result_e53eebb9ebb0a096']['undoAction'] = "unsave";window['sj_result_e53eebb9ebb0a096']['relativeJobAge'] = "Today";window['sj_result_e53eebb9ebb0a096']['jobKey'] = "e53eebb9ebb0a096"; window['sj_result_e53eebb9ebb0a096']['myIndeedAvailable'] = true; window['sj_result_e53eebb9ebb0a096']['showMoreActionsLink'] = window['sj_result_e53eebb9ebb0a096']['showMoreActionsLink'] || false; window['sj_result_e53eebb9ebb0a096']['resultNumber'] = 14; window['sj_result_e53eebb9ebb0a096']['jobStateChangedToSaved'] = false; window['sj_result_e53eebb9ebb0a096']['searchState'] = "q=Data &amp; Database&amp;l=san+francisco%2C+ca&amp;sort=date"; window['sj_result_e53eebb9ebb0a096']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_e53eebb9ebb0a096']['saveJobFailed'] = false; window['sj_result_e53eebb9ebb0a096']['removeJobFailed'] = false; window['sj_result_e53eebb9ebb0a096']['requestPending'] = false; window['sj_result_e53eebb9ebb0a096']['currentPage'] = "serp"; window['sj_result_e53eebb9ebb0a096']['sponsored'] = true;window['sj_result_e53eebb9ebb0a096']['reportJobButtonEnabled'] = false; window['sj_result_e53eebb9ebb0a096']['showMyJobsHired'] = false; window['sj_result_e53eebb9ebb0a096']['showSaveForSponsored'] = true; window['sj_result_e53eebb9ebb0a096']['showJobAge'] = true; window['sj_result_e53eebb9ebb0a096']['showHolisticCard'] = true; window['sj_result_e53eebb9ebb0a096']['showDislike'] = true; window['sj_result_e53eebb9ebb0a096']['showKebab'] = true; window['sj_result_e53eebb9ebb0a096']['showReport'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>

# %%
job_page = jobcard.find('a').attrs['href']
job_res = requests.get("http://www.indeed.com" + job_page)
job_soup = BeautifulSoup(job_res.content, 'lxml')
job_soup.find('div', {'id':'jobDescriptionText'}).text.strip().replace('\n', ' ')
# Out:
# "Bioinformatics Programmer III involves developing and utilizing computational tools and systems to analyze and interpret biological or other research data. The person in this role utilizes and develops algorithms, computational techniques, and statistical methodologies; helps in the design of new experiments; implements end-user needs in database searching and integration; maintains the computational infrastructure and tracks the flow of samples and information for large-scale studies; and provides web-based bioinformatics and access to public and proprietary databases.The primary role of this position is to use skills as a seasoned, experienced bioinformatics programming professional with a broad understanding of computational algorithms and systems to apply computational and statistical methods to analyze and interpret data obtained from the next generation of functional genomics screens. This Bioinformatics Programmer III will demonstrate good judgment in selecting methods and techniques for obtaining solutions and operates independently.  Please note: This is a full time contract position through May 2024.   LABORATORY FOR GENOMICS RESEARCH / BIOCHEMISTRY & BIOPHYSICS The Laboratory for Genomics Research (LGR) is a new functional genomics center on the UCSF Mission Bay campus. The LGR represents a novel hybrid model that brings together researchers from UC Berkeley, UC San Francisco, and GlaxoSmithKline under a single roof working on projects both together and independently. The new laboratory will also be a resource for investigators at both UC campuses who will be able to access and use the LGR to answer their own biological and biomedical questions. The LGR will use CRISPR/Cas9-based functional genomics tools to decipher biological functions of genes, identifying new drug targets and developing new technologies that will advances discovery in both academia and industry. A focus of the lab is to deploy deeper phenotypic readouts such as single cell sequencing and imaging to uncover new biology. The LGR is searching for motivated candidates to contribute to the computational and bioinformatic efforts to analyze and interpret these unique genomic datasets.ABOUT UCSF The University of California, San Francisco (UCSF) is a leading university dedicated to promoting health worldwide through advanced biomedical research, graduate-level education in the life sciences and health professions, and excellence in patient care. It is the only campus in the 10-campus UC system dedicated exclusively to the health sciences. Department Description The Biochemistry & Biophysics Department is comprised of 26 faculty members and about 200 students and postdoctoral fellows pursuing a range of biological problems encompassing biochemistry, genetics, and cell, structural and developmental biology. The faculty are committed to graduate education and actively engaged in shaping the highly collaborative environment that makes UCSF a special place. Required Qualifications Bachelor's degree in biological science, computational / programming, or related area and minimum 3 years experience / or equivalent combination of experience / training.Thorough knowledge of bioinformatics methods and applications programming relating to NGS data analysis in the context of CRISPR screens and human geneticsThorough knowledge of bioinformatics programming design, modification and implementation.Communication skills to work with both technical and non-technical personnel in multiple fields of expertise and at various levels in the organization.Ability to interface with management on a regular basis.Self motivated, work independently or as part of a team, able to learn quickly, meet deadlines and demonstrate problem solving skills. Preferred Qualifications   MS or PhD in biological science, computational / programming, or related area and / or equivalent experience / training Strong project management skills. Thorough knowledge of modern biology and applicable field ...

# %% [markdown]
# ## `def indeed_scrape`
#
# - Indeed is very sensitive to web crawling and will block your IP address after 10 pages.
# - For this initial scraping, I was able to do 100 pages (result ended after 76 loops), but for routine scrapings, 10 pages should be enough to fetch new postings.

# %%
def indeed_scrape(keywords, location, maxpage) 
    keywords = keywords.replace(' ', '+')
    location = location.replace(' ', '+')
    url = 'https://www.indeed.com/jobs?q='+keywords+'&l='+location+'&sort=date'
    postings = []

    for i in range(0, maxpage):
        if (i == 0):
            page_append = ''
        else:
            page_append = "&start=" + str(i * 10)

        # get page
        res = requests.get(url + page_append)
        print(f'res {i+1} code: ', res.status_code)

        if res.status_code != 200:
            pass

        else:
            soup = BeautifulSoup(res.content, 'lxml')
            jobcards = soup.find_all('div', {'class': 'jobsearch-SerpJobCard'})
            for jobcard in jobcards:
                posting = {}
                posting['title'] = jobcard.find('h2', {'class': 'title'}).text.strip().replace('\n', '_')
                posting['company'] = jobcard.find('span', {'class': 'company' }).text.strip().replace('\n', '')       
                posting['location'] = jobcard.find(['div', 'span'], {'class': 'location accessible-contrast-color-location'}).text.strip()
                posting['summary'] = jobcard.find('div', {'class': 'summary'}).text.strip()

                job_page = jobcard.find('a').attrs['href']
                job_res = requests.get("http://www.indeed.com" + job_page)
                job_soup = BeautifulSoup(job_res.content, 'lxml')


                try:
                    posting['description'] = job_soup.find('div', {'class':'jobsearch-jobDescriptionText'}).text.strip()
                except:
                    if AttributeError:
                        pass

                try:
                    posting['salary'] = jobcard.find('div', {'class': 'salarySnippet holisticSalary'}).text.strip()
                except:
                    posting['salary'] = 'None'

                try:
                    posting['rating'] = jobcard.find('span', {'class': 'ratingsContent'}).text.strip()
                except:
                    posting['rating'] = 'None'        

                postings.append(posting)
                df = pd.DataFrame(postings)
                df.to_csv(f'df_{i+1}.csv', index=False)
        time.sleep(5)

    df = pd.DataFrame(postings)

    
    
    
keywords = 'data database'
location = 'san francisco, ca'
maxpage = 100 
indeed_scrape(keywords, location, maxpage)
# Out:
# res 1 code:  200
# res 2 code:  200
# res 3 code:  200
# res 4 code:  200
# res 5 code:  200
# res 6 code:  200
# res 7 code:  200
# res 8 code:  200
# res 9 code:  200
# res 10 code:  200
# res 11 code:  200
# res 12 code:  200
# res 13 code:  200
# res 14 code:  200
# res 15 code:  200
# res 16 code:  200
# res 17 code:  200
# res 18 code:  200
# res 19 code:  200
# res 20 code:  200
# res 21 code:  200
# res 22 code:  200
# res 23 code:  200
# res 24 code:  200
# res 25 code:  200
# res 26 code:  200
# res 27 code:  200
# res 28 code:  200
# res 29 code:  200
# res 30 code:  200
# res 31 code:  200
# res 32 code:  200
# res 33 code:  200
# res 34 code:  200
# res 35 code:  200
# res 36 code:  200
# res 37 code:  200
# res 38 code:  200
# res 39 code:  200
# res 40 code:  200
# res 41 code:  200
# res 42 code:  200
# res 43 code:  200
# res 44 code:  200
# res 45 code:  200
# res 46 code:  200
# res 47 code:  200
# res 48 code:  200
# res 49 code:  200
# res 50 code:  200
# res 51 code:  200
# res 52 code:  200
# res 53 code:  200
# res 54 code:  200
# res 55 code:  200
# res 56 code:  200
# res 57 code:  200
# res 58 code:  200
# res 59 code:  200
# res 60 code:  200
# res 61 code:  200
# res 62 code:  200
# res 63 code:  200
# res 64 code:  200
# res 65 code:  200
# res 66 code:  200
# res 67 code:  200
# res 68 code:  200
# res 69 code:  200
# res 70 code:  200
# res 71 code:  200
# res 72 code:  200
# res 73 code:  200
# res 74 code:  200
# res 75 code:  200
# res 76 code:  200
# res 77 code:  200
# res 78 code:  200
# res 79 code:  200
# res 80 code:  200
# res 81 code:  200
# res 82 code:  200
# res 83 code:  200
# res 84 code:  200
# res 85 code:  200
# res 86 code:  200
# res 87 code:  200
# res 88 code:  200
# res 89 code:  200
# res 90 code:  200
# res 91 code:  200
# res 92 code:  200
# res 93 code:  200
# res 94 code:  200
# res 95 code:  200
# res 96 code:  200
# res 97 code:  200
# res 98 code:  200
# res 99 code:  200
# res 100 code:  200

# %% [markdown]
# ### Check if the data frame looks as expected

# %%
df.head()
# Out:
#                                        title  \
# 0              Pharmacy Technician (Walmart)
# 1      Application Architect (1.0 FTE, Days)
# 2                        Major Gifts Officer
# 3  Consulting Member of Technical Staff, OCI
# 4                    Staff Software Engineer
#
#                                    company  \
# 0                        Wal-Mart Pharmacy
# 1       Lucile Packard Children's Hospital
# 2  Community Overcoming Relationship ABUSE
# 3                                   Oracle
# 4           Galileo Financial Technologies
#
#                                  location  \
# 0                      Richmond, CA 94806
# 1     Menlo Park, CA (Lorelei Manor area)
# 2  San Mateo, CA 94403 (Bay Meadows area)
# 3                        Redwood City, CA
# 4                       San Francisco, CA
#
#                                                                                                                                                               summary  \
# 0          Maintains pharmacy systems and technology (for example, inventory systems, automated medication counting machines) by preparing informational and related…
# 1      Must have minimum of 3 years of experience with each of the following: Programming/Scripting, including Java, JavaScript, Angular JS, SQL, Shell, Perl, HTML;…
# 2       Manage the agency’s donor database (currently Bloomerang) and supervise administrative staff on completing daily tasks associated with donor data management.
# 3                 Expertise in relational database and NoSQL database.\nExperience with SQL and data management.\nNo Visa Sponsorship is available for this position.
# 4  Ability to both design schema and query data in a full-featured implementation of SQL.\nYou’ll be extending and maintaining the financial backend that powers our…
#
#                                                                                                                                                                                                                                                                                                                                                                                                        description  \
# 0  What you'll doMaintains pharmacy systems and technology (for example, inventory systems, automated medication counting machines) by preparing informational and related records and reports to ensure accurate data and system compliance with policies and regulations; monitoring inventory levels and expiration dates for pharmaceuticals; calibrating machines; applying settings to pill or capsule sp...
# 1  Information Technology\n1.0 FTE, 8 Hour Day Shift\n\nLucile Packard Children's Hospital Stanford is the heart and soul of Stanford Children’s Health. Nationally ranked and internationally recognized, our 311-bed hospital is devoted entirely to pediatrics and obstetrics. Our six centers of excellence provide comprehensive services and deep expertise in key obstetric and pediatric areas: brain &...
# 2  FULL TIME and EXEMPT\n\nReports to: Director of Development (IED FOR NOW)\n\nSchedule of Hours: M-F FT, weekends as needed\n\nPosition Remote Eligible: During the pandemic the role may be performed remote, however, THIS ROLE IS BASED OUT OF SAN MATEO, CA, AND THE SELECTED INDIVIDUAL MUST BE LOCAL TO THE AREA\n\nMandated Reporter: No\nABOUT THE ORGANIZATION\n\nCommunity Overcoming Relationship ...
# 3  Consulting Member of Technical Staff, OCI-210007GT\n\nNo Visa Sponsorship is available for this position.\n\nApplicants are required to read, write, and speak the following languages: English\n\nPreferred Qualifications\nThe Oracle Cloud Infrastructure (OCI) team can provide you the opportunity to build and operate a suite of massive scale, integrated cloud services in a broadly distributed, m...
# 4  Who we are\nWelcoming, collaborative and having the opportunity to make an impact - is how our employees describe working here. Galileo is a financial technology company that provides innovative and revolutionary software products and services that power some of the world's largest Fintechs. We are the only payments innovator that applies tech and engineering capabilities to empower Fintechs a...
#
#   salary rating
# 0   None    3.5
# 1   None    4.0
# 2   None    2.5
# 3   None    3.8
# 4   None    3.2

# %%
df.shape
# Out:
# (1147, 7)

# %% [markdown]
# - although the scraping shows more than 1100 rows, many are expected to be duplicates, so we want to drop the duplicated rows then export as a csv file.

# %%
df = df.drop_duplicates()

# %%
df.to_csv('job_df.csv', index=False)
